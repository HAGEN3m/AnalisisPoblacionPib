# %% [markdown]
# ### # 05 - Conclusiones
#
# #### 📌 Objetivo general del proyecto
#
# Este proyecto tuvo como objetivo analizar indicadores económicos a nivel global, con foco en la **relación entre población, ingreso nacional bruto (GNI) y producto interno bruto (PIB)**. Se buscó además evaluar la posibilidad de **predecir el PIB** utilizando modelos de regresión lineal.
#
# ---
#
# #### 🔎 Principales hallazgos del análisis exploratorio
#
# * Se identificaron **tendencias de crecimiento poblacional global** consistentes, con un aumento sostenido desde el año 2000.
# * El **PIB y el GNI** mostraron una distribución muy sesgada, dominada por pocos países con valores extremadamente altos (outliers).
# * Existió una **alta correlación entre población y PIB**, y especialmente entre GNI y PIB.
#
# ---
#
# #### 🧼 Limpieza y preparación de datos
#
# * Se eliminaron columnas irrelevantes y aquellas con alto porcentaje de valores nulos.
# * Se homogenizaron nombres de columnas y se guardó un dataset limpio.
# * Se trataron outliers solo de forma visual y descriptiva, manteniéndolos en el modelo por su relevancia macroeconómica.
#
# ---
#
# #### 📈 Modelo predictivo y resultados
#
# * Se entrenó un modelo de **regresión lineal múltiple** para predecir el PIB usando como variables independientes la **población** y el **GNI**.
# * El modelo obtuvo métricas de desempeño sobresalientes:
#
#   * **MAE** ≈ 4.34 mil millones USD
#   * **RMSE** ≈ 14.19 mil millones USD
#   * **R²** ≈ 0.9997 (muy buen ajuste)
# * El gráfico de dispersión de predicción vs realidad mostró una línea ajustada casi ideal (y = x).
#
# ---
#
# #### 📊 Visualizaciones finales
#
# Se presentó una **gráfica final de performance del modelo** mostrando que las predicciones se alinean muy bien con los valores reales del PIB.
#
# ---
#
# #### 💡 Conclusiones generales
#
# * Es posible **predecir el PIB de un país con altísima precisión** utilizando solo población y GNI como variables explicativas.
# * Esto evidencia el fuerte vínculo entre el tamaño del país (demográfico y económico) y su producto interno bruto.
# * Las visualizaciones mostraron también cómo se concentran los mayores valores económicos en pocos países.
#
# ---
#
# #### 🔜 Próximos pasos o mejoras posibles
#
# * Probar modelos más complejos (como regresión polinómica, árboles o modelos no lineales).
# * Incluir otras variables como inflación, exportaciones, educación, etc.
# * Crear un dashboard interactivo con herramientas como Power BI o Tableau para comunicar los insights a un público no técnico.
