# %% [markdown]
# ### # 05 - Conclusiones
#
# #### 📌 Objetivo general del proyecto
#
# El propósito de este análisis fue explorar indicadores económicos globales, centrándonos en la relación entre **población**, **ingreso nacional bruto (GNI)** y **producto interno bruto (PIB)**. Además, se buscó evaluar la viabilidad de **predecir el PIB** a partir de modelos estadísticos sencillos, como la regresión lineal.
#
# ---
#
# #### 🔎 Principales hallazgos del análisis exploratorio
#
# * Se observó un **crecimiento constante de la población mundial**, especialmente sostenido a partir del año 2000.
# * El **PIB y el GNI** presentaron una **distribución desigual**, altamente concentrada en pocas economías, lo que generó presencia de valores extremos (outliers).
# * La **correlación entre GNI y PIB fue altísima**, lo que sugiere una fuerte relación entre ingreso y producción económica. También se encontró una correlación notable con la variable población.
#
# ---
#
# #### 🧼 Proceso de limpieza y preparación de datos
#
# * Se eliminaron columnas con alta proporción de valores nulos o sin relevancia analítica.
# * Se renombraron variables para mantener consistencia y claridad en el análisis.
# * Los valores extremos fueron identificados y analizados, pero se conservaron debido a su importancia macroeconómica.
#
# ---
#
# #### 📈 Modelo predictivo: regresión lineal
#
# * Se construyó un modelo de **regresión lineal múltiple**, utilizando como variables independientes la **población** y el **GNI** para estimar el PIB.
# * Los resultados fueron muy sólidos, mostrando que ambas variables permiten explicar casi completamente la variabilidad del PIB.
#
#   **Resultados del modelo:**
#   - **MAE** ≈ 4.34 mil millones USD
#   - **RMSE** ≈ 14.19 mil millones USD
#   - **R²** ≈ 0.9997
#
# * El gráfico de predicción vs. valores reales mostró un ajuste casi perfecto a la diagonal, indicando que el modelo funciona muy bien sobre los datos disponibles.
#
# ---
#
# #### 📊 Visualizaciones del desempeño
#
# * Se incluyó una visualización final que compara los valores reales y los predichos por el modelo, confirmando gráficamente la precisión del mismo.
#
# ---
#
# #### 💡 Conclusiones generales
#
# * Con solo dos variables —población y GNI— es posible **predecir el PIB de forma precisa y confiable**.
# * Este hallazgo confirma la influencia directa del tamaño poblacional y del ingreso nacional sobre la producción económica de un país.
# * A través del análisis visual, también se destacó cómo **pocas economías concentran la mayor parte de la riqueza mundial**, lo que reafirma las desigualdades estructurales existentes.
#
# ---
#
# #### 🔜 Posibles líneas futuras
#
# * Explorar **modelos más complejos**, como árboles de decisión, regresiones no lineales o redes neuronales.
# * Incluir nuevas variables explicativas como nivel educativo, exportaciones, inflación, acceso a salud, entre otros.
# * Desarrollar dashboards interactivos que permitan a usuarios no técnicos explorar los datos y hallazgos de forma dinámica.
#
# ---
#
# ## 📊 Visualizaciones Finales con Power BI
#
# Para reforzar la comunicación visual del proyecto, se creó un dashboard en **Power BI**, tomando como base el dataset limpio generado en Python.
#
# 📁 El archivo puede encontrarse en la carpeta:
# `visualizaciones/dashboard_indicadores_economicos.pbix`
#
# ---
#
# ### 🧩 Contenido del dashboard:
#
# - **📈 Evolución del PIB global por año (USD)**
#   Representa la tendencia del crecimiento económico mundial entre 1960 y la actualidad.
#
# - **🗺️ Mapa del PIB acumulado por país**
#   Visualiza de forma geográfica cómo se distribuye la producción económica total. Se observa una concentración evidente en América del Norte, Europa y Asia oriental.
#
# - **🧮 GNI, PIB y población por país**
#   Gráfico de burbujas que permite identificar qué países combinan altos ingresos con grandes poblaciones, y cómo se comportan en relación con el PIB.
#
# - **📊 Evolución del PIB por país a lo largo de los años**
#   Gráfico de barras apiladas que permite comparar la evolución de cada país en el tiempo. Ideal para detectar trayectorias de crecimiento.
#
# - **💰 PIB per cápita acumulado por país**
#   Este gráfico destaca qué economías tienen mejor rendimiento económico por persona, revelando casos como Mónaco, Liechtenstein o Suiza.
#
# ---
#
# Estas visualizaciones refuerzan los hallazgos del análisis y permiten que cualquier usuario —técnico o no— pueda explorar las diferencias económicas entre países de forma visual, clara e interactiva.
